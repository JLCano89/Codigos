# %% [markdown]
# <a href="https://colab.research.google.com/github/JLCano89/Codigos/blob/main/Actividad_Final_Jose_Luis_Cano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar dependencias necesarias
# !pip install streamlit pandas pdfplumber openpyxl pyngrok

# Registrar el authtoken de ngrok
from pyngrok import ngrok
ngrok.set_auth_token("2vHdXhKnHStJMyaTcMOzksMDyJL_3fq6EyJ1deNqQrbQ5xAYJ")

# Guardar el código de la app en app.py
code = '''
import streamlit as st
import pandas as pd
import pdfplumber
import os

st.title("Aplicación de Análisis de Datos")

st.sidebar.header("Subir archivo")
uploaded_file = st.sidebar.file_uploader("Cargar archivo", type=["csv", "xlsx", "xls", "pdf"])

if uploaded_file is not None:
    filename = uploaded_file.name
    ext = os.path.splitext(filename)[1].lower()

    if ext == ".pdf":
        text = ""
        with pdfplumber.open(uploaded_file) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text
        st.subheader("Contenido del PDF")
        st.text(text)

    elif ext in [".csv", ".xls", ".xlsx"]:
        try:
            if ext == ".csv":
                df = pd.read_csv(uploaded_file)
            else:
                df = pd.read_excel(uploaded_file)

            st.subheader("Vista previa de los datos")
            st.dataframe(df.head(10))

            if st.button("Mostrar todos los datos"):
                st.dataframe(df)

            st.subheader("Estadísticas Descriptivas")
            st.write(df.describe())

            # Visualización de datos
            st.subheader("Visualización de Datos")

            # Selección de columna para gráficas
            numeric_cols = df.select_dtypes(include=["float64", "int64"]).columns.tolist()
            categorical_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()

            if numeric_cols:
                col_to_plot = st.selectbox("Seleccionar columna numérica para histograma", numeric_cols)
                st.bar_chart(df[col_to_plot].value_counts().sort_index())
                st.line_chart(df[col_to_plot])

            if categorical_cols:
                col_cat = st.selectbox("Seleccionar columna categórica para gráfico de barras", categorical_cols)
                st.bar_chart(df[col_cat].value_counts())

            # Gráfico de dispersión si hay al menos 2 columnas numéricas
            if len(numeric_cols) >= 2:
                st.subheader("Gráfico de Dispersión")
                col_x = st.selectbox("Eje X", numeric_cols, index=0)
                col_y = st.selectbox("Eje Y", numeric_cols, index=1)
                st.write(f"Gráfico entre {col_x} y {col_y}")
                st.scatter_chart(df[[col_x, col_y]])

            # Descargar los datos procesados
            st.subheader("Descargar datos procesados")
            csv = df.to_csv(index=False).encode("utf-8")
            st.download_button(
                label="Descargar CSV",
                data=csv,
                file_name="procesado.csv",
                mime="text/csv"
            )

        except Exception as e:
            st.error(f"Error al procesar el archivo: {e}")
    else:
        st.warning("Formato de archivo no compatible.")
'''

# Guardar el archivo
with open("app.py", "w") as f:
    f.write(code)

# Iniciar el túnel y la app
public_url = ngrok.connect("http://localhost:8501")
print(f"🚀 Tu aplicación Streamlit está disponible aquí: {public_url}")

# Ejecutar Streamlit (en segundo plano)
# !streamlit run app.py &>/content/logs.txt &
# !tail -f /content/logs.txt
# Out:
# ...
# 🚀 Tu aplicación Streamlit está disponible aquí: NgrokTunnel: "https://9f5d-34-80-120-62.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.120.62:8501
#
# 2025-04-04 22:43:48.554 Serialization of dataframe to Arrow table was unsuccessful. Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/dataframe_util.py", line 822, in convert_pandas_df_to_arrow_bytes
#     table = pa.Table.from_pandas(df)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pyarrow/table.pxi", line 4751, in pyarrow.lib.Table.from_pandas
#   File "/usr/local/lib/python3.11/dist-packages/pyarrow/pandas_compat.py", line 625, in dataframe_to_arrays
#     arrays = [convert_column(c, f)
#              ^^^^^^^^^^^^^^^^^^^^^
# ...
